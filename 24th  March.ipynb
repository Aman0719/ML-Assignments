# %%
import pandas  as pd

# %%
data=pd.read_csv("winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# #### Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %%
Ans-

The wine quality dataset contains information on the physicochemical properties of red and white wine samples, 
as well as a sensory quality score assigned to each sample by a panel of experts. 

Some of the key features of the dataset include:

1.Fixed acidity: 
This refers to the concentration of non-volatile acids in the wine. 
It plays a role in determining the wine's pH, which can affect its flavor, stability, and microbiological safety.

2.Volatile acidity: 
This refers to the concentration of volatile acids in the wine.
It can contribute to a wine's aroma and flavor, but high levels can indicate spoilage or fermentation problems.

3.Citric acid: 
This is one of the primary organic acids found in grapes and can contribute to a wine's acidity and freshness.

4.Residual sugar: 
This refers to the amount of sugar remaining in the wine after fermentation. 
It can affect the wine's sweetness, body, and mouthfeel.

5.Chlorides:
This refers to the concentration of salt in the wine.
It can affect the wine's flavor and stability.

6.Free sulfur dioxide:
This is a preservative added to wine to prevent spoilage and oxidation. 
It can affect the wine's aroma, flavor, and color.

7.Total sulfur dioxide: 
This is the total amount of sulfur dioxide present in the wine, including both free and bound forms.
It can affect the wine's stability and aging potential.

8.Density:
This refers to the density of the wine relative to water. 
It can provide information on the wine's alcohol content and can affect its mouthfeel.

9.pH:
This is a measure of the acidity or alkalinity of the wine.
It can affect the wine's flavor, stability, and microbiological safety.

10.Sulphates: 
This refers to the concentration of sulfates in the wine.
It can affect the wine's aroma, flavor, and stability.

11.Alcohol: 
This is the percentage of alcohol by volume in the wine. 
It can affect the wine's body, mouthfeel, and flavor.

The importance of each feature in predicting wine quality can vary depending on the specific analysis being performed and the individual preferences of the taster.
However, in general, acidity, pH, and alcohol content are considered to be important predictors of wine quality.
Acidity and pH can affect the wine's flavor, balance, and stability, while alcohol content can contribute to the wine's body, mouthfeel, and overall sensory appeal.
Other features, such as residual sugar and sulfur dioxide, can also play a role in determining wine quality, particularly in terms of sweetness, aroma, and preservation.

# %% [markdown]
# #### Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.

# %%
#Ans-

#First of all we will search for any missing values in our dataset:
    
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
Since we have no missing valuesin this data set, so we do not need to handle, but generally we can handle it by,

1.Mean/Median/Mode imputation: 
In this method, missing values are replaced with the mean, median, or mode value of the available data for that feature. 
This is a simple and quick approach that can preserve the overall distribution of the data.
However, it may not be appropriate for all types of data, and can potentially introduce bias if the missing values are not missing at random.

2.Hot-deck imputation: 
This method involves filling in missing values using the value of a randomly selected non-missing observation from the same dataset. 
This approach can preserve the relationships between variables and can be useful for preserving the variance and covariance structures of the data. 
However, it may not be appropriate for large datasets or datasets with many missing values.

3.Multiple imputation:
In this method, missing values are imputed multiple times based on the observed data and their own distributional properties. 
This approach can capture the variability and uncertainty associated with the missing data and can produce more accurate estimates of the missing values.
However, it can be computationally intensive and may require a large number of imputations to produce stable results.

4.K-nearest neighbors imputation:
This method involves identifying the K-nearest neighbors (based on distance or similarity measures) to the observation with missing values, and imputing the missing value based on the average of the non-missing values of those neighbors.
This approach can be useful for preserving the local relationships between variables and can produce good results for continuous variables. 
However, it may not be appropriate for datasets with many missing values or categorical variables.

Each of these imputation techniques has its own advantages and disadvantages, and the choice of method will depend on the specific characteristics of the dataset and the goals of the analysis.
It is important to carefully consider the potential biases and limitations of each approach when deciding which method to use.

# %% [markdown]
# #### Detailed Advantages and Disadvantages of each Technique

# %%
 Here are some advantages and disadvantages of each technique of handling missing data:

1.Mean/Median/Mode imputation:

Advantages:
-Simple and easy to implement.
-Preserves the overall distribution of the data.
-Works well when data is missing at random.

Disadvantages:
-Can introduce bias if the data is not missing at random.
-Does not account for the uncertainty associated with the imputed values.
-Can underestimate the standard errors and affect statistical tests.


2.Hot-deck imputation:

Advantages:
-Preserves the relationships between variables.
-Can be useful for preserving the variance and covariance structures of the data.
-Can work well for small datasets or datasets with few missing values.

Disadvantages:
-May not be appropriate for large datasets or datasets with many missing values.
-Can introduce bias if the data is not missing at random.
-Imputed values may be influenced by the randomly selected observation.


3.Multiple imputation:

Advantages:
-Accounts for the uncertainty associated with the missing data.
-Can produce more accurate estimates of the missing values.
-Can handle missing data for both continuous and categorical variables.

Disadvantages:
-Can be computationally intensive and require a large number of imputations to produce stable results.
-Requires assumptions about the distributional properties of the data.
-Can be sensitive to the imputation model specification.


4.K-nearest neighbors imputation:

Advantages:
-Preserves the local relationships between variables.
-Can work well for continuous variables.
-Can handle missing data for both continuous and categorical variables.

Disadvantages:
-May not be appropriate for datasets with many missing values.
-Imputed values can be influenced by the choice of distance or similarity measures.
-Requires assumptions about the distributional properties of the data.

# %% [markdown]
# #### Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?

# %%
#Ans- First we will load the student data

df=pd.read_csv('stud.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
Ans-

In this dataset, there are multiple features that can effect the student performance,
it can be checked and performed through two ways:
1. Visualisation
2. Regression Analysis

# %%
Before any method, we will perform following operations:
    
Check Missing values in the dataset
Check Duplicates in dataset
Check data type of each column
Check the number of unique values of each column (like Gender-Male and Female)
Check statistics of data set (like info and describe)
Check various categories present in the different categorical column

# %%
1. Visualization:
To begin analyzing the relationships between these variables, we could calculate descriptive statistics and correlations. 
For example, we could calculate means and standard deviations for each of the three test scores and 
examine through visualization whether there are any significant differences between groups based on gender, race/ethnicity, parental education level, or lunch type.

# %%
df['total_score']=(df['math_score']+df['reading_score']+df['writing_score'])
df['average']=df['total_score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
#Importing Libraries

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Impact of Gender on Performance

fig,axis=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='gender')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Conlusion
#
# #### Female student tend to perform well than male students, as they have higher mean score

# %%
# Impact of Lunch on Performance
sns.histplot(data=df,x='average',kde=True,hue='lunch')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Conclusion
#
# #### Standard Lunch help students perform well in exams

# %%
Similarly, we can perform the visualization of other features with the average score and conclude the realtionship between them

# %%
2. Regression analysis

To analyze these factors using statistical techniques, we can use regression analysis. 
Regression analysis allows us to examine the relationship between a dependent variable (such as exam performance) and one or more independent variables (such as parental education level, study time, absences, and gender).

Here are the steps we can take to analyze these factors using regression analysis:

1.Data preparation: 
We will need to clean the dataset and check for missing values or outliers that could affect the analysis.

2.Variable selection: 
We will need to select the independent variables (predictors) that we want to include in the analysis, such as parental education level, study time, absences, and gender.

3.Model selection: 
We will need to select a regression model that is appropriate for our data, such as linear regression, logistic regression, or multiple regression.

4.Model fitting: 
We will need to fit the regression model to our data and evaluate its performance, using techniques such as cross-validation or the coefficient of determination (R-squared).

# %% [markdown]
# #### Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?

# %%
Ans-

Feature engineering is the process of selecting and transforming raw data into features that are suitable for machine learning models.
In the context of the student performance data set, feature engineering involves selecting and transforming the variables in the data set to create new features that may be more informative for predicting test scores.

Here are the steps I would take to perform feature engineering on this data set:

1.Select relevant features: 
Based on domain knowledge and exploratory data analysis, select a subset of features that are likely to be relevant for predicting test scores. 
In this data set, some relevant features might include gender, race/ethnicity, parental level of education, lunch type, and completion of test preparation course.

2.Transform categorical variables:
Many of the variables in the data set are categorical, such as race/ethnicity and lunch type. 
To include these variables in a machine learning model, we need to transform them into numerical features.
One common approach is one-hot encoding, where we create a new binary feature for each category in the original variable. 
For example, we might create binary features for each race/ethnicity category (e.g., African American, Asian) and lunch type category (e.g., standard, free/reduced).

3.Normalize numerical variables:
Some variables in the data set, such as the test scores, are already numerical.
However, they may have different scales, which can make it difficult for machine learning algorithms to learn from them.
To address this issue, we can normalize the numerical variables to have a mean of 0 and a standard deviation of 1.

4.Create new features:
We can also create new features by combining existing features or performing calculations.
For example, we could create a feature that represents the average of the three test scores or a feature that represents the difference between the reading and writing scores.

5.Feature selection:
Once we have created new features, we can use feature selection techniques to identify the most informative features for predicting test scores.
One approach is to use a correlation matrix to identify highly correlated features and remove one of the features.
Another approach is to use a machine learning model with built-in feature selection, such as LASSO regression, which can identify the most important features while penalizing model complexity.

Overall, the feature engineering process involves selecting relevant features, transforming categorical variables, normalizing numerical variables, creating new features, and selecting the most informative features for predicting test scores. 
This process can help improve the performance of machine learning models by providing more informative and relevant features.

# %% [markdown]
# ### Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?

# %%
#Ans-

#To load the data

data=pd.read_csv('winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ans-

To perform the EDA on this dataset, we will first follow the following steps

Check Missing values in the dataset
Check Duplicates in dataset
Check data type of each column
Check the number of unique values of each column (like Gender-Male and Female)
Check statistics of data set (like info and describe)
Check various categories present in the different categorical column

# %%
#EDA

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Check the first few rows of the data
print(data.head())

# Check the data types and 
print(data.info())

# check missing values
print(data.isnull().sum())
      
# Generate summary statistics of the data
print(data.describe())

# Visualize the distribution of each feature using histograms and density plots
fig, axs = plt.subplots(ncols=6, nrows=2, figsize=(20, 10))
axs = axs.flatten()

for i, column in enumerate(wine_data.columns):
    sns.histplot(data[column], ax=axs[i])
    sns.kdeplot(data[column], ax=axs[i], color='red')
plt.tight_layout()
plt.show()

# Visualize the correlation between features using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
From the above operation, we can conclude that there are no missing values and
will have all the information about the uniques values and types of each column.

# %%
fig, axs = plt.subplots(ncols=6, nrows=2, figsize=(20, 10))
axs = axs.flatten()

for i, column in enumerate(data.columns[:-1]):
    sns.histplot(data[column], ax=axs[i])
    sns.kdeplot(data[column], ax=axs[i], color='red')
plt.tight_layout()
plt.show()

# %%
From these plots, we can see that several features do not appear to be normally distributed, including:

fixed acidity
volatile acidity
citric acid
residual sugar
free sulfur dioxide
total sulfur dioxide
alcohol

To improve normality, we can apply various transformations to these features. 
Here are some possible transformations:

1.Log transformation: 
This can be applied to features with right-skewed distributions, such as residual sugar, free sulfur dioxide, and total sulfur dioxide. 
The log transformation can help reduce the effect of extreme values and make the distribution more symmetric.

2.Square root transformation: 
This can be applied to features with highly skewed distributions, such as volatile acidity and citric acid. 
The square root transformation can help reduce the skewness and make the distribution more bell-shaped.

# %%
#Let's take example of Log transformation

# Log Transformation
data_log = data.copy()
data_log['volatile acidity'] = np.log(data['volatile acidity'])
data_log['total sulfur dioxide'] = np.log(data['total sulfur dioxide'])
data_log['free sulfur dioxide'] = np.log(data['free sulfur dioxide'])
data_log['residual sugar'] = np.log(data['residual sugar'])
data_log['fixed acidity'] = np.log(data['fixed acidity'])
data_log['citric acid'] = np.log(data['citric acid'])
data_log['alcohol'] = np.log(data['alcohol'])
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#We can then create histograms and probability density plots of the transformed variables to see if normality has improved:

fig, axs = plt.subplots(ncols=7, nrows=1, figsize=(20, 10))
axs = axs.flatten()

for i, column in enumerate(['volatile acidity', 'total sulfur dioxide', 'free sulfur dioxide', 'residual sugar','fixed acidity','citric acid', 'alcohol']):
    sns.histplot(data_log[column], ax=axs[i])
    sns.kdeplot(data_log[column], ax=axs[i], color='red')
plt.tight_layout()
plt.show()

# %%
From these plots, we can see that log transformation have improved normality in the non-normal variables. 
However, it is important to note that the specific transformation used may depend on the characteristics of the data and the specific machine learning algorithm being used.

# %% [markdown]
# #### Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance inthe data?

# %%
#Ans-

'''Here is an example code to perform principal component analysis (PCA) on the wine quality dataset 
and determine the minimum number of principal components required to explain 90% of the variance:'''


import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Load the wine quality dataset
wine_data = pd.read_csv('winequality-red.csv')

# Separate the target variable
target = wine_data['quality']
wine_data = wine_data.drop('quality', axis=1)

# Normalize the data
wine_data_norm = (wine_data - wine_data.mean()) / wine_data.std()

# Perform PCA
pca = PCA()
pca.fit(wine_data_norm)

# Calculate the cumulative sum of explained variance ratios
var_cumsum = np.cumsum(pca.explained_variance_ratio_)

# Find the minimum number of principal components required to explain 90% of the variance
n_components = np.where(var_cumsum >= 0.9)[0][0] + 1
print(f"Minimum number of principal components required to explain 90% of the variance: {n_components}")

# Plot the cumulative sum of explained variance ratios
plt.plot(var_cumsum)
plt.xlabel('Number of principal components')
plt.ylabel('Cumulative sum of explained variance ratios')
plt.show()
# Out:
# Minimum number of principal components required to explain 90% of the variance: 7

# %%
This code will perform PCA on the wine quality dataset, normalize the data, and calculate the cumulative sum of explained variance ratios. 
It will then find the minimum number of principal components required to explain 90% of the variance, 
and plot the cumulative sum of explained variance ratios.

Here are some explanations for each part of the code:

1.wine_data['quality']: 
This line separates the target variable from the wine quality dataset.

2.(wine_data - wine_data.mean()) / wine_data.std(): 
This line normalizes the wine quality dataset by subtracting the mean and dividing by the standard deviation.

3.pca.fit(wine_data_norm): 
This line fits the PCA model to the normalized wine quality dataset.

4.np.cumsum(pca.explained_variance_ratio_): 
This line calculates the cumulative sum of explained variance ratios.

5.np.where(var_cumsum >= 0.9)[0][0] + 1: 
This line finds the minimum number of principal components required to explain 90% of the variance.

6.plt.plot(var_cumsum): 
This line plots the cumulative sum of explained variance ratios.

By performing PCA, we can reduce the number of features in the wine quality dataset while retaining most of the information.
In this example, the minimum number of principal components required to explain 90% of the variance is 7.
This means that we can reduce the number of features from 11 to 7 while retaining most of the information in the data.
